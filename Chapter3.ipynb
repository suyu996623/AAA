# %%
# !python --version

# %%
# !pip list

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 第3章 Pandas資料結構
# ## Series資料結構

# %%
# 傳入一個串列
dict1 = {1:100,2:200}
dict2 = {'a':'A','b':'B'}
S1 = pd.Series([1.0,2.0,3.0])
S1
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# dtype: float64

# %%
# 指定索引
S2 = pd.Series([1,2,3,4],index = [1000,2000,3000,4000])
S2
# Out:
# 1000    1
# 2000    2
# 3000    3
# 4000    4
# dtype: int64

# %%
S2[3000]
# Out:
# 3

# %%
# 傳入一個字典
S3 = pd.Series({"a":1,"b":2,"c":3,"d":4})
S3
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
S3['d']
# Out:
# 4

# %%
# 利用index方法取得Series的索引
S1.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
indx1 = S2.index

print(indx1)

type(indx1.values)
# Out:
# Int64Index([1000, 2000, 3000, 4000], dtype='int64')
# numpy.ndarray

# %%
# 利用values方法取得Series的值
S1.values
# Out:
# array([1., 2., 3.])

# %%
S2.values
# Out:
# array([1, 2, 3, 4])

# %%
S2.size
# Out:
# 4

# %% [markdown]
# ## DataFrame 表格型資料結構

# %%
a1 = np.array([[1,2,3]])
a1.shape
# Out:
# (1, 3)

# %%
# 傳入一個列表
df1 = pd.DataFrame([["a"],["b"],["c"],["d"]])
df1
# Out:
#    0
# 0  a
# 1  b
# 2  c
# 3  d

# %%
# 傳入一個嵌套列表
df2 = pd.DataFrame([["a","A"],["b","B"],["c","C"],["d","D"]])
df2
# Out:
#    0  1
# 0  a  A
# 1  b  B
# 2  c  C
# 3  d  D

# %%
#設定欄索引
df31 = pd.DataFrame([["a","A"],["b","B"],["c","C"],["d","D"]], columns = ["小寫","大寫"])
df31
# Out:
#   小寫 大寫
# 0  a  A
# 1  b  B
# 2  c  C
# 3  d  D

# %%
#設定列索引
df32 = pd.DataFrame([["a","A"],["b","B"],["c","C"],["d","D"]], index = ["一","二","三","四"])
df32
# Out:
#    0  1
# 一  a  A
# 二  b  B
# 三  c  C
# 四  d  D

# %%
#列、欄索引同時設定
df33 = pd.DataFrame([["a","A"],["b","B"],["c","C"],["d","D"]], columns = ["小寫","大寫"], index = ["一","二","三","四"])
df33
# Out:
#   小寫 大寫
# 一  a  A
# 二  b  B
# 三  c  C
# 四  d  D

# %%
#傳入一個字典
data = {"小寫":["a","b","c","d"],"大寫":["A","B","C","D"]}
df41 = pd.DataFrame(data)
df41
# Out:
#   小寫 大寫
# 0  a  A
# 1  b  B
# 2  c  C
# 3  d  D

# %%
data = {"小寫":["a","b","c","d"],"大寫":["A","B","C","D"]}
df42 = pd.DataFrame(data,index = ["一","二","三","四"])
df42
# Out:
#   小寫 大寫
# 一  a  A
# 二  b  B
# 三  c  C
# 四  d  D

# %%
#利用columns方法取得DataFrame的欄索引
df2.columns
# Out:
# RangeIndex(start=0, stop=2, step=1)

# %%
df33.columns
# Out:
# Index(['小寫', '大寫'], dtype='object')

# %%
#利用index方法取得DataFrame的列索引
df2.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df33.index
# Out:
# Index(['一', '二', '三', '四'], dtype='object')

# %%
index1 = pd.MultiIndex.from_tuples([('d', 1), ('d', 2),('e', 2)], names=['n', 'v'])
df = pd.DataFrame({ "a" : [4 ,5, 6], 
                    "b" : [7, 8, 9], 
                    "c" : [10, 11, 12]}, 
                    index = index1)
df
# Out:
#      a  b   c
# n v
# d 1  4  7  10
#   2  5  8  11
# e 2  6  9  12

# %%
tuples = [('iphone13', 'red'), ('iphone13', 'blue'),('iphone14', 'red'), ('iphone14', 'blue')]
index1 = pd.MultiIndex.from_tuples(tuples, names=('產品型號', '產品顏色'))

df = pd.DataFrame({ "單價" : [20000,21000,30000,31000], "相機畫素" : ['4000px','5000px','4000px','5000px']},index = index1)

# %%
df
# Out:
#                   單價    相機畫素
# 產品型號     產品顏色
# iphone13 red   20000  4000px
#          blue  21000  5000px
# iphone14 red   30000  4000px
#          blue  31000  5000px

# %%
df.T
# Out:
# 產品型號 iphone13         iphone14
# 產品顏色      red    blue      red    blue
# 單價      20000   21000    30000   31000
# 相機畫素   4000px  5000px   4000px  5000px

# %%
tuples = [('iphone13', 'red'), ('iphone13', 'blue'),('iphone14', 'red'), ('iphone14', 'blue')]

df = pd.DataFrame(
                    { "單價" : [20000,21000,30000,31000], "相機畫素" : ['4000px','5000px','4000px','5000px']},
                    index = pd.MultiIndex.from_tuples(tuples, names=('產品型號', '產品顏色'))
                 )
